# %% [markdown]
# https://maps.conservation.ca.gov/calgem/findwells/#data_s=id%3AdataSource_2-Well-0%3A135190
#
#  Well finder map that I can use to see if I can find the wells in our datasets and any dates
#
# # Check this site
# This site appears to have accurate records of the geothermal wells that match our data. We can grab a date, called date drilled, in the website
#  https://geosteam.conservation.ca.gov/ Theres also this site, may be better
